# %%
import pandas as pd

# %%
data=pd.read_csv("books.csv")

# %%
data=data[data.columns.drop(["isbn","isbn13","image_url","small_image_url"])]
print(data.info())
print("*"*60)
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1354 entries, 0 to 1353
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   book_id                    1354 non-null   int64
#  1   goodreads_book_id          1354 non-null   int64
#  2   best_book_id               1354 non-null   int64
#  3   work_id                    1354 non-null   int64
#  4   books_count                1354 non-null   int64
#  5   authors                    1354 non-null   object
#  6   original_publication_year  1351 non-null   float64
#  7   original_title             1302 non-null   object
#  8   title                      1354 non-null   object
#  9   language_code              1245 non-null   object
#  10  average_rating             1354 non-null   float64
#  11  ratings_count              1354 non-null   int64
#  12  work_ratings_count         1354 non-null   int64
# ...

# %%
data_without_nullrows=data.dropna()
print(data.shape)
print(data_without_nullrows.shape)
# Out:
# (1354, 19)
# (1197, 19)

# %%
Harry_with_nulls=data[data["title"].str.contains("Harry Potter",case=False)]
Harry_with_nulls
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 1           2                  3             3   4640799          491
# 6          18                  5             5   2402163          376
# 8          21                  2             2   2809203          307
# 9          23              15881         15881   6231171          398
# 10         24                  6             6   3046572          332
# 11         25             136251        136251   2963218          263
# 12         27                  1             1  41335427          275
# 96        422             862041        862041   2962492           76
# 613      3753                 10            10  21457570            6
# 1036     7018             483445        483445    471792           42
# 1266     9048               2002          2002   8621948            5
#
#                                       authors  original_publication_year  \
# ...

# %%
Harry_without_nulls=data_without_nullrows[data_without_nullrows["original_title"].str.contains("Harry Potter",case=False)]
Harry_without_nulls
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 1           2                  3             3   4640799          491
# 6          18                  5             5   2402163          376
# 8          21                  2             2   2809203          307
# 9          23              15881         15881   6231171          398
# 10         24                  6             6   3046572          332
# 11         25             136251        136251   2963218          263
# 12         27                  1             1  41335427          275
# 96        422             862041        862041   2962492           76
# 613      3753                 10            10  21457570            6
# 1036     7018             483445        483445    471792           42
#
#                                       authors  original_publication_year  \
# 1                 J.K. Rowling, Mary GrandPré                     1997.0
# ...

# %%
Harry_with_nulls.loc[:,["book_id","title","average_rating"]]
# Out:
#       book_id                                              title  \
# 1           2  Harry Potter and the Sorcerer's Stone (Harry P...
# 6          18  Harry Potter and the Prisoner of Azkaban (Harr...
# 8          21  Harry Potter and the Order of the Phoenix (Har...
# 9          23  Harry Potter and the Chamber of Secrets (Harry...
# 10         24  Harry Potter and the Goblet of Fire (Harry Pot...
# 11         25  Harry Potter and the Deathly Hallows (Harry Po...
# 12         27  Harry Potter and the Half-Blood Prince (Harry ...
# 96        422           Harry Potter Boxset (Harry Potter, #1-7)
# 613      3753       Harry Potter Collection (Harry Potter, #1-6)
# 1036     7018  The Magical Worlds of Harry Potter: A Treasury...
# 1266     9048  Harry Potter Schoolbooks Box Set: Two Classic ...
#
#       average_rating
# 1               4.44
# 6               4.53
# 8               4.46
# 9               4.37
# 10              4.53
# 11              4.61
# 12              4.54
# ...

# %%
print(Harry_with_nulls.ratings_count.max())
max_rating=Harry_with_nulls.ratings_count.max()
# Out:
# 4602479

# %%
max_row=Harry_with_nulls[Harry_with_nulls.ratings_count==max_rating]
max_row
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 1        2                  3             3  4640799          491
#
#                        authors  original_publication_year  \
# 1  J.K. Rowling, Mary GrandPré                     1997.0
#
#                              original_title  \
# 1  Harry Potter and the Philosopher's Stone
#
#                                                title language_code  \
# 1  Harry Potter and the Sorcerer's Stone (Harry P...           eng
#
#    average_rating  ratings_count  work_ratings_count  work_text_reviews_count  \
# 1            4.44        4602479             4800065                    75867
#
#    ratings_1  ratings_2  ratings_3  ratings_4  ratings_5
# 1      75504     101676     455024    1156318    3011543

# %%
best_seller = data[data['ratings_count'] == max_rating]

print(f"The best selling Harry Potter book is: {best_seller['title'].values[0]}")
# Out:
# The best selling Harry Potter book is: Harry Potter and the Sorcerer's Stone (Harry Potter, #1)

# %%
average_rating = data['average_rating'].mean()
median_rating = data['average_rating'].median()
print("Average Rating:", average_rating)
print("Median Rating:", median_rating)
# Out:
# Average Rating: 3.999357459379616
# Median Rating: 4.0

# %%
df = pd.read_csv('books.csv')

hp_books = df[df['authors'].str.contains('J.K. Rowling')]

total_ratings = hp_books['ratings_count'].sum()
average_rating = total_ratings / len(hp_books)

print(f'Average rating of Harry Potter books is {average_rating}')
# Out:
# Average rating of Harry Potter books is 1310798.8333333333
